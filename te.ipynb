# %%
import os

# %%
import tempfile 
TEMP_DIR=tempfile.gettempdir() #here we will store the temporary files 
DB_PATH = os.path.join(TEMP_DIR, "expenses.db")

# %%
DB_PATH
# Out:
# 'C:\\Users\\aashi\\AppData\\Local\\Temp\\expenses.db'
